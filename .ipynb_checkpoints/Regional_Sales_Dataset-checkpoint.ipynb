# %%
### Problem Statement
Analyze Acme Co.’s 2014–2018 sales data to identify key revenue and profit drivers across products, channels, and regions; uncover seasonal trends and outliers;
and align performance against budgets. Use these insights to optimize pricing, promotions, and market expansion for sustainable growth and reduced concentration risk.

# %%
## 🎯 **Objective**## 🎯 **Objective**
Deliver actionable insights from Acme Co.’s 2014–2018 sales data to:

- Identify top-performing products, channels, and regions driving revenue and profit  
- Uncover seasonal trends and anomalies for optimized planning  
- Spot pricing and margin risks from outlier transactions  
- Inform pricing, promotion, and market-expansion strategies  

These findings will guide the design of a Power BI dashboard to support strategic decision-making and sustainable growth.

# %%
# **📥 Setup & Configuration**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_sale= pd.read_excel('Updated_Sales_Orders.xlsx')
df_sale.head(2)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2023-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2020-01-01                   96  Distributor           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost
# 0               6      2499.1     14994.6         1824.343
# 1              11      2351.7     25868.7         1269.918

# %%
sd = pd.read_excel('Regional Sales Dataset.xlsx', sheet_name= None)
sd
# Out:
# {'Sales Orders':         OrderNumber  OrderDate  Customer Name Index      Channel  \
#  0       SO - 000225 2014-01-01                  126    Wholesale
#  1      SO - 0003378 2014-01-01                   96  Distributor
#  2      SO - 0005126 2014-01-01                    8    Wholesale
#  3      SO - 0005614 2014-01-01                   42       Export
#  4      SO - 0005781 2014-01-01                   73    Wholesale
#  ...             ...        ...                  ...          ...
#  64099  SO - 0007573 2018-02-28                   74    Wholesale
#  64100  SO - 0007706 2018-02-28                   51       Export
#  64101  SO - 0007718 2018-02-28                  136  Distributor
#  64102  SO - 0008084 2018-02-28                  158  Distributor
#  64103  SO - 0008654 2018-02-28                   22  Distributor
#
#        Currency Code Warehouse Code  Delivery Region Index  \
#  0               USD         AXW291                    364
#  1               USD         AXW291                    488
#  2               USD         AXW291                    155
#  3               USD         AXW291                    473
#  4               USD         AXW291                    256
#  ...             ...            ...                    ...
#  64099           USD         AXW291                    825
#  64100           USD         NXH382                    444
#  64101           USD         AXW291                    312
#  64102           USD         AXW291                    737
#  64103           USD         AXW291                    807
#
#         Product Description Index  Order Quantity  Unit Price  Line Total  \
#  0                             27               6      2499.1     14994.6
#  1                             20              11      2351.7     25868.7
#  2                             26               6       978.2      5869.2
#  3                              7               7      2338.3     16368.1
#  4                              8               8      2291.4     18331.2
#  ...                          ...             ...         ...         ...
#  64099                         26              12      1815.7     21788.4
#  64100                         21               6       864.3      5185.8
#  64101                         13              11      3953.0     43483.0
#  64102                         20               7      3959.7     27717.9
#  64103                         15               8       998.3      7986.4
#
#         Total Unit Cost
#  0             1824.343
#  1             1269.918
#  2              684.740
#  3             1028.852
#  4             1260.270
#  ...                ...
#  64099          980.478
#  64100          579.081
#  64101         2648.510
#  64102         2930.178
#  64103          848.555
#
#  [64104 rows x 12 columns],
#  'Customers':      Customer Index Customer Names
#  0                 1  Geiss Company
#  1                 2  Jaxbean Group
#  2                 3     Ascend Ltd
#  3                 4      Eire Corp
#  4                 5   Blogtags Ltd
#  ..              ...            ...
#  170             171   Accord Group
#  171             172   BB17 Company
#  172             173          H Ltd
#  173             174   Tekfly Group
#  174             175   SHISEIDO Ltd
#
#  [175 rows x 2 columns],
#  'Regions':       id        name                                   county state_code  \
#  0      1      Auburn                               Lee County         AL
#  1      2  Birmingham           Shelby County/Jefferson County         AL
#  2      3     Decatur           Limestone County/Morgan County         AL
#  3      4      Dothan  Dale County/Houston County/Henry County         AL
#  4      5      Hoover           Shelby County/Jefferson County         AL
#  ..   ...         ...                                      ...        ...
#  989  990      Racine                            Racine County         WI
#  990  991    Waukesha                          Waukesha County         WI
#  991  992  West Allis                         Milwaukee County         WI
#  992  993      Casper                           Natrona County         WY
#  993  994    Cheyenne                           Laramie County         WY
#
#           state  type  latitude  longitude  area_code  population  households  \
#  0      Alabama  City  32.60986  -85.48078        334       62059       21767
#  1      Alabama  City  33.52744  -86.79905        205      212461       89972
#  2      Alabama  City  34.57332  -86.99214        256       55437       22294
#  3      Alabama  City  31.23370  -85.40682        334       68567       25913
#  4      Alabama  City  33.37695  -86.80558        205       84848       32789
#  ..         ...   ...       ...        ...        ...         ...         ...
#  989  Wisconsin  City  42.72613  -87.78285        262       77742       29851
#  990  Wisconsin  City  43.01168  -88.23148        262       71970       28331
#  991  Wisconsin  City  43.01668  -88.00703        414       60620       27457
#  992    Wyoming  City  42.86663 -106.31308        307       60285       23814
#  993    Wyoming  City  41.13998 -104.82025        307       63335       25130
#
#       median_income  land_area  water_area        time_zone
#  0            38342  152375113     2646161  America/Chicago
#  1            31061  378353942     6591013  America/Chicago
#  2            41496  141006257    17594716  America/Chicago
#  3            42426  232166237      835468  America/Chicago
#  4            77146  122016784     2553332  America/Chicago
#  ..             ...        ...         ...              ...
#  989          41455   40111757     8282116  America/Chicago
#  990          59547   65856921      700602  America/Chicago
#  991          45221   29480532       60789  America/Chicago
#  992          57790   68507280      911081   America/Denver
#  993          58219   69964749      282335   America/Denver
#
#  [994 rows x 15 columns],
#  'State Regions':        Column1               Column2    Column3
#  0   State Code                 State     Region
#  1           AL               Alabama      South
#  2           AR              Arkansas      South
#  3           AZ               Arizona       West
#  4           CA            California       West
#  5           CO              Colorado       West
#  6           CT           Connecticut  Northeast
#  7           DC  District of Columbia      South
#  8           DE              Delaware      South
#  9           FL               Florida      South
#  10          GA               Georgia      South
#  11          HI                Hawaii       West
#  12          IA                  Iowa    Midwest
#  13          ID                 Idaho       West
#  14          IL              Illinois    Midwest
#  15          IN               Indiana    Midwest
#  16          KS                Kansas    Midwest
#  17          KY              Kentucky      South
#  18          LA             Louisiana      South
#  19          MA         Massachusetts  Northeast
#  20          MD              Maryland      South
#  21          ME                 Maine  Northeast
#  22          MI              Michigan    Midwest
#  23          MN             Minnesota    Midwest
#  24          MO              Missouri    Midwest
#  25          MS           Mississippi      South
#  26          MT               Montana       West
#  27          NC        North Carolina      South
#  28          ND          North Dakota    Midwest
#  29          NE              Nebraska    Midwest
#  30          NH         New Hampshire  Northeast
#  31          NJ            New Jersey  Northeast
#  32          NM            New Mexico       West
#  33          NV                Nevada       West
#  34          NY              New York  Northeast
#  35          OH                  Ohio    Midwest
#  36          OK              Oklahoma      South
#  37          OR                Oregon       West
#  38          PA          Pennsylvania  Northeast
#  39          RI          Rhode Island  Northeast
#  40          SC        South Carolina      South
#  41          SD          South Dakota    Midwest
#  42          TN             Tennessee      South
#  43          TX                 Texas      South
#  44          UT                  Utah       West
#  45          VA              Virginia      South
#  46          WA            Washington       West
#  47          WI             Wisconsin    Midwest
#  48          WY               Wyoming       West,
#  'Products':     Index Product Name
#  0       1    Product 1
#  1       2    Product 2
#  2       3    Product 3
#  3       4    Product 4
#  4       5    Product 5
#  5       6    Product 6
#  6       7    Product 7
#  7       8    Product 8
#  8       9    Product 9
#  9      10   Product 10
#  10     11   Product 11
#  11     12   Product 12
#  12     13   Product 13
#  13     14   Product 14
#  14     15   Product 15
#  15     16   Product 16
#  16     17   Product 17
#  17     18   Product 18
#  18     19   Product 19
#  19     20   Product 20
#  20     21   Product 21
#  21     22   Product 22
#  22     23   Product 23
#  23     24   Product 24
#  24     25   Product 25
#  25     26   Product 26
#  26     27   Product 27
#  27     28   Product 28
#  28     29   Product 29
#  29     30   Product 30,
#  '2017 Budgets':    Product Name  2017 Budgets
#  0     Product 1   3016489.209
#  1     Product 2   3050087.565
#  2     Product 3   2642352.432
#  3     Product 4   2885560.824
#  4     Product 5   3925424.542
#  5     Product 6   1672229.416
#  6     Product 7    889737.555
#  7     Product 8   1085037.329
#  8     Product 9    710415.405
#  9    Product 10    864331.624
#  10   Product 11   1230458.484
#  11   Product 12   1356976.996
#  12   Product 13   3720639.645
#  13   Product 14   4028698.409
#  14   Product 15   3299478.315
#  15   Product 16   2062061.144
#  16   Product 17   2119616.824
#  17   Product 18   2309499.045
#  18   Product 19   1645841.600
#  19   Product 20   2067108.120
#  20   Product 21    959899.218
#  21   Product 22    663601.902
#  22   Product 23   1135815.758
#  23   Product 24    756557.970
#  24   Product 25   5342315.484
#  25   Product 26   5685138.270
#  26   Product 27    964940.231
#  27   Product 28   1003867.767
#  28   Product 29    594471.570
#  29   Product 30   1011609.684}

# %%
df_customers = sd['Customers']
df_Products = sd['Products']
df_region = sd['Regions']
df_state_rega = sd['State Regions']
df_budgets = sd['2017 Budgets']

# %%
print(f'''
df_sale shape : {df_sale.shape}
df_customers shape : {df_customers.shape}
df_Products shape: {df_Products.shape}
df_regions shape: {df_region.shape}
df_state_reg shape: {df_state_rega.shape}
df_budgets shape: {df_budgets.shape}''')
# Out:
# df_sale shape : (64104, 12)
# df_customers shape : (175, 2)
# df_Products shape: (30, 2)
# df_regions shape: (994, 15)
# df_state_reg shape: (49, 3)
# df_budgets shape: (30, 2)

# %%
df_budgets.head()
# Out:
#   Product Name  2017 Budgets
# 0    Product 1   3016489.209
# 1    Product 2   3050087.565
# 2    Product 3   2642352.432
# 3    Product 4   2885560.824
# 4    Product 5   3925424.542

# %%
df_budgets.isnull().sum()
# Out:
# Product Name    0
# 2017 Budgets    0
# dtype: int64

# %%
df_state_rega.columns = df_state_rega.iloc[0]
df_state_rega = df_state_rega.drop([0]).reset_index(drop=True)

# %%
df_state_rega.head()
# Out:
# 0 State Code       State Region
# 0         AL     Alabama  South
# 1         AR    Arkansas  South
# 2         AZ     Arizona   West
# 3         CA  California   West
# 4         CO    Colorado   West

# %%
df_state_rega.isnull().sum()
# Out:
# Column1    0
# Column2    0
# Column3    0
# dtype: int64

# %%
df_region.isnull().sum()
# Out:
# id               0
# name             0
# county           0
# state_code       0
# state            0
# type             0
# latitude         0
# longitude        0
# area_code        0
# population       0
# households       0
# median_income    0
# land_area        0
# water_area       0
# time_zone        0
# dtype: int64

# %%
df_region.head()
# Out:
#    id        name                                   county state_code  \
# 0   1      Auburn                               Lee County         AL
# 1   2  Birmingham           Shelby County/Jefferson County         AL
# 2   3     Decatur           Limestone County/Morgan County         AL
# 3   4      Dothan  Dale County/Houston County/Henry County         AL
# 4   5      Hoover           Shelby County/Jefferson County         AL
#
#      state  type  latitude  longitude  area_code  population  households  \
# 0  Alabama  City  32.60986  -85.48078        334       62059       21767
# 1  Alabama  City  33.52744  -86.79905        205      212461       89972
# 2  Alabama  City  34.57332  -86.99214        256       55437       22294
# 3  Alabama  City  31.23370  -85.40682        334       68567       25913
# 4  Alabama  City  33.37695  -86.80558        205       84848       32789
#
#    median_income  land_area  water_area        time_zone
# 0          38342  152375113     2646161  America/Chicago
# 1          31061  378353942     6591013  America/Chicago
# 2          41496  141006257    17594716  America/Chicago
# 3          42426  232166237      835468  America/Chicago
# 4          77146  122016784     2553332  America/Chicago

# %%
df_customers.isnull().sum()
# Out:
# Customer Index    0
# Customer Names    0
# dtype: int64

# %%
df_customers.head()
# Out:
#    Customer Index Customer Names
# 0               1  Geiss Company
# 1               2  Jaxbean Group
# 2               3     Ascend Ltd
# 3               4      Eire Corp
# 4               5   Blogtags Ltd

# %%
df_region.isnull().sum()
# Out:
# id               0
# name             0
# county           0
# state_code       0
# state            0
# type             0
# latitude         0
# longitude        0
# area_code        0
# population       0
# households       0
# median_income    0
# land_area        0
# water_area       0
# time_zone        0
# dtype: int64

# %%
df_region.head()
# Out:
#    id        name                                   county state_code  \
# 0   1      Auburn                               Lee County         AL
# 1   2  Birmingham           Shelby County/Jefferson County         AL
# 2   3     Decatur           Limestone County/Morgan County         AL
# 3   4      Dothan  Dale County/Houston County/Henry County         AL
# 4   5      Hoover           Shelby County/Jefferson County         AL
#
#      state  type  latitude  longitude  area_code  population  households  \
# 0  Alabama  City  32.60986  -85.48078        334       62059       21767
# 1  Alabama  City  33.52744  -86.79905        205      212461       89972
# 2  Alabama  City  34.57332  -86.99214        256       55437       22294
# 3  Alabama  City  31.23370  -85.40682        334       68567       25913
# 4  Alabama  City  33.37695  -86.80558        205       84848       32789
#
#    median_income  land_area  water_area        time_zone
# 0          38342  152375113     2646161  America/Chicago
# 1          31061  378353942     6591013  America/Chicago
# 2          41496  141006257    17594716  America/Chicago
# 3          42426  232166237      835468  America/Chicago
# 4          77146  122016784     2553332  America/Chicago

# %%
df_customers.isnull().sum()
# Out:
# Customer Index    0
# Customer Names    0
# dtype: int64

# %%
df_customers.head()
# Out:
#    Customer Index Customer Names
# 0               1  Geiss Company
# 1               2  Jaxbean Group
# 2               3     Ascend Ltd
# 3               4      Eire Corp
# 4               5   Blogtags Ltd

# %%
# merge with customers
rj = df_sale.merge(
    df_customers,
    how='left',
    left_on= 'Customer Name Index',
    right_on= 'Customer Index'
)
rj.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2023-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2020-01-01                   96  Distributor           USD
# 2  SO - 0005126 2020-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2022-01-01                   42       Export           USD
# 4  SO - 0005781 2021-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost  Customer Index  \
# 0               6      2499.1     14994.6         1824.343             126
# 1              11      2351.7     25868.7         1269.918              96
# 2               6       978.2      5869.2          684.740               8
# 3               7      2338.3     16368.1         1028.852              42
# 4               8      2291.4     18331.2         1260.270              73
#
#      Customer Names
# 0     Rhynoodle Ltd
# 1    Thoughtmix Ltd
# 2   Amerisourc Corp
# 3  Colgate-Pa Group
# 4     Deseret Group

# %%
# merge with producs
rj = rj.merge(
    df_Products,
    how='left',
    left_on= 'Product Description Index',
    right_on= 'Index'
)
rj.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2023-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2020-01-01                   96  Distributor           USD
# 2  SO - 0005126 2020-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2022-01-01                   42       Export           USD
# 4  SO - 0005781 2021-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost  Customer Index  \
# 0               6      2499.1     14994.6         1824.343             126
# 1              11      2351.7     25868.7         1269.918              96
# 2               6       978.2      5869.2          684.740               8
# 3               7      2338.3     16368.1         1028.852              42
# 4               8      2291.4     18331.2         1260.270              73
#
#      Customer Names  Index Product Name
# 0     Rhynoodle Ltd     27   Product 27
# 1    Thoughtmix Ltd     20   Product 20
# 2   Amerisourc Corp     26   Product 26
# 3  Colgate-Pa Group      7    Product 7
# 4     Deseret Group      8    Product 8

# %%
# merge with Reions
rj = rj.merge(
    df_region,
    how='left',
    left_on= 'Delivery Region Index',
    right_on= 'id'
)
rj.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2023-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2020-01-01                   96  Distributor           USD
# 2  SO - 0005126 2020-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2022-01-01                   42       Export           USD
# 4  SO - 0005781 2021-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  type  latitude  longitude area_code  \
# 0               6      2499.1  ...  City  32.08354  -81.09983       912
# 1              11      2351.7  ...  City  39.61366  -86.10665       317
# 2               6       978.2  ...  City  37.66243 -121.87468       925
# 3               7      2338.3  ...  City  39.16533  -86.52639       812
# 4               8      2291.4  ...  Town  41.77524  -72.52443       959
#
#    population households  median_income  land_area water_area  \
# 0      145674      52798          36466  268318796   13908113
# 1       55586      20975          54176   72276415       1883
# 2       79510      26020         124759   62489257     386195
# 3       84067      30232          30019   60221613     475857
# 4       58007      24141          63158   70972793     720300
#
#                       time_zone
# 0              America/New York
# 1  America/Indiana/Indianapolis
# 2           America/Los Angeles
# 3  America/Indiana/Indianapolis
# 4              America/New York
#
# [5 rows x 31 columns]

# %%
# merge with State index
rj = rj.merge(
    df_state_rega[['State Code','Region']],
    how='left',
    left_on= 'state_code',
    right_on= 'State Code'
)
rj.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2023-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2020-01-01                   96  Distributor           USD
# 2  SO - 0005126 2020-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2022-01-01                   42       Export           USD
# 4  SO - 0005781 2021-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  longitude  area_code  population  \
# 0               6      2499.1  ...  -81.09983        912      145674
# 1              11      2351.7  ...  -86.10665        317       55586
# 2               6       978.2  ... -121.87468        925       79510
# 3               7      2338.3  ...  -86.52639        812       84067
# 4               8      2291.4  ...  -72.52443        959       58007
#
#   households  median_income  land_area  water_area  \
# 0      52798          36466  268318796    13908113
# 1      20975          54176   72276415        1883
# 2      26020         124759   62489257      386195
# 3      30232          30019   60221613      475857
# 4      24141          63158   70972793      720300
#
#                       time_zone State Code     Region
# 0              America/New York         GA      South
# 1  America/Indiana/Indianapolis         IN    Midwest
# 2           America/Los Angeles         CA       West
# 3  America/Indiana/Indianapolis         IN    Midwest
# 4              America/New York         CT  Northeast
#
# [5 rows x 33 columns]

# %%
df_budgets = df_budgets.columns.str.lower()
df_budgets
# Out:
# Index(['product name', '2017 budgets'], dtype='object')

# %%
# Customer Indexabs
# Index
# id
#State Code 

# clean up redundant columns 

drop_to = ['Customer Index','Index','id','State Code']
rj = rj.drop(columns=drop_to,errors= 'ignore')
rj.head()
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2023-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2020-01-01                   96  Distributor           USD
# 2  SO - 0005126 2020-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2022-01-01                   42       Export           USD
# 4  SO - 0005781 2021-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  latitude  longitude area_code population  \
# 0               6      2499.1  ...  32.08354  -81.09983       912     145674
# 1              11      2351.7  ...  39.61366  -86.10665       317      55586
# 2               6       978.2  ...  37.66243 -121.87468       925      79510
# 3               7      2338.3  ...  39.16533  -86.52639       812      84067
# 4               8      2291.4  ...  41.77524  -72.52443       959      58007
#
#   households median_income  land_area water_area  \
# 0      52798         36466  268318796   13908113
# 1      20975         54176   72276415       1883
# 2      26020        124759   62489257     386195
# 3      30232         30019   60221613     475857
# 4      24141         63158   70972793     720300
#
#                       time_zone     Region
# 0              America/New York      South
# 1  America/Indiana/Indianapolis    Midwest
# 2           America/Los Angeles       West
# 3  America/Indiana/Indianapolis    Midwest
# 4              America/New York  Northeast
#
# [5 rows x 29 columns]

# %%
# convert all columns to lower case for consistency and easier access
rj.columns = rj.columns.str.lower()
rj.columns.values
# Out:
# array(['ordernumber', 'orderdate', 'customer name index', 'channel',
#        'currency code', 'warehouse code', 'delivery region index',
#        'product description index', 'order quantity', 'unit price',
#        'line total', 'total unit cost', 'customer names', 'product name',
#        'name', 'county', 'state_code', 'state', 'type', 'latitude',
#        'longitude', 'area_code', 'population', 'households',
#        'median_income', 'land_area', 'water_area', 'time_zone', 'region'],
#       dtype=object)

# %%
keep_to = [
    'ordernumber',
    'orderdate',
    'customer names',
    'channel', 
    'order quantity', 
    'product name',
    'unit price', 
    'line total' ,
    'total unit cost',
    'state_code',
    'state',
    'county',
    'region',
    'longitude',
    'latitude'
]

# %%
rj = rj[keep_to]
rj.head()
# Out:
#     ordernumber  orderdate    customer names      channel  order quantity  \
# 0   SO - 000225 2023-01-01     Rhynoodle Ltd    Wholesale               6
# 1  SO - 0003378 2020-01-01    Thoughtmix Ltd  Distributor              11
# 2  SO - 0005126 2020-01-01   Amerisourc Corp    Wholesale               6
# 3  SO - 0005614 2022-01-01  Colgate-Pa Group       Export               7
# 4  SO - 0005781 2021-01-01     Deseret Group    Wholesale               8
#
#   product name  unit price  line total  total unit cost state_code  \
# 0   Product 27      2499.1     14994.6         1824.343         GA
# 1   Product 20      2351.7     25868.7         1269.918         IN
# 2   Product 26       978.2      5869.2          684.740         CA
# 3    Product 7      2338.3     16368.1         1028.852         IN
# 4    Product 8      2291.4     18331.2         1260.270         CT
#
#          state           county     region  longitude  latitude
# 0      Georgia   Chatham County      South  -81.09983  32.08354
# 1      Indiana   Johnson County    Midwest  -86.10665  39.61366
# 2   California   Alameda County       West -121.87468  37.66243
# 3      Indiana    Monroe County    Midwest  -86.52639  39.16533
# 4  Connecticut  Hartford County  Northeast  -72.52443  41.77524

# %%
rj.isnull().sum()
# Out:
# ordernumber        0
# orderdate          0
# customer names     0
# channel            0
# order quantity     0
# product name       0
# unit price         0
# line total         0
# total unit cost    0
# state_code         0
# state              0
# county             0
# region             0
# longitude          0
# latitude           0
# dtype: int64

# %%
rj = rj.rename(columns={
     'ordernumber':'order_name',
    'orderdate':'order_date',
    'customer names':'customer_name',
    'channel':'channel_name',
    'order quantity':'order_qty',
    'product name':'product_name',
    'unit price':'unit_name', 
    'line total':'line_total' ,
    'total unit cost':'total_unit_cost',
})

# %%
rj.head()
# Out:
#      order_name order_date     customer_name channel_name  order_qty  \
# 0   SO - 000225 2023-01-01     Rhynoodle Ltd    Wholesale          6
# 1  SO - 0003378 2020-01-01    Thoughtmix Ltd  Distributor         11
# 2  SO - 0005126 2020-01-01   Amerisourc Corp    Wholesale          6
# 3  SO - 0005614 2022-01-01  Colgate-Pa Group       Export          7
# 4  SO - 0005781 2021-01-01     Deseret Group    Wholesale          8
#
#   product_name  unit_name  line_total  total_unit_cost state_code  \
# 0   Product 27     2499.1     14994.6         1824.343         GA
# 1   Product 20     2351.7     25868.7         1269.918         IN
# 2   Product 26      978.2      5869.2          684.740         CA
# 3    Product 7     2338.3     16368.1         1028.852         IN
# 4    Product 8     2291.4     18331.2         1260.270         CT
#
#          state           county     region  longitude  latitude
# 0      Georgia   Chatham County      South  -81.09983  32.08354
# 1      Indiana   Johnson County    Midwest  -86.10665  39.61366
# 2   California   Alameda County       West -121.87468  37.66243
# 3      Indiana    Monroe County    Midwest  -86.52639  39.16533
# 4  Connecticut  Hartford County  Northeast  -72.52443  41.77524

# %%
rj['total_cost'] = rj['order_qty']* rj['total_unit_cost']
rj.head(5)
# Out:
#      order_name order_date     customer_name channel_name  order_qty  \
# 0   SO - 000225 2023-01-01     Rhynoodle Ltd    Wholesale          6
# 1  SO - 0003378 2020-01-01    Thoughtmix Ltd  Distributor         11
# 2  SO - 0005126 2020-01-01   Amerisourc Corp    Wholesale          6
# 3  SO - 0005614 2022-01-01  Colgate-Pa Group       Export          7
# 4  SO - 0005781 2021-01-01     Deseret Group    Wholesale          8
#
#   product_name  unit_name  line_total  total_unit_cost state_code  \
# 0   Product 27     2499.1     14994.6         1824.343         GA
# 1   Product 20     2351.7     25868.7         1269.918         IN
# 2   Product 26      978.2      5869.2          684.740         CA
# 3    Product 7     2338.3     16368.1         1028.852         IN
# 4    Product 8     2291.4     18331.2         1260.270         CT
#
#          state           county     region  longitude  latitude  total_cost
# 0      Georgia   Chatham County      South  -81.09983  32.08354   10946.058
# 1      Indiana   Johnson County    Midwest  -86.10665  39.61366   13969.098
# 2   California   Alameda County       West -121.87468  37.66243    4108.440
# 3      Indiana    Monroe County    Midwest  -86.52639  39.16533    7201.964
# 4  Connecticut  Hartford County  Northeast  -72.52443  41.77524   10082.160

# %%
rj['profit'] = rj['line_total'] - rj['total_cost']
rj.head()
# Out:
#      order_name order_date     customer_name channel_name  order_qty  \
# 0   SO - 000225 2023-01-01     Rhynoodle Ltd    Wholesale          6
# 1  SO - 0003378 2020-01-01    Thoughtmix Ltd  Distributor         11
# 2  SO - 0005126 2020-01-01   Amerisourc Corp    Wholesale          6
# 3  SO - 0005614 2022-01-01  Colgate-Pa Group       Export          7
# 4  SO - 0005781 2021-01-01     Deseret Group    Wholesale          8
#
#   product_name  unit_name  line_total  total_unit_cost state_code  \
# 0   Product 27     2499.1     14994.6         1824.343         GA
# 1   Product 20     2351.7     25868.7         1269.918         IN
# 2   Product 26      978.2      5869.2          684.740         CA
# 3    Product 7     2338.3     16368.1         1028.852         IN
# 4    Product 8     2291.4     18331.2         1260.270         CT
#
#          state           county     region  longitude  latitude  total_cost  \
# 0      Georgia   Chatham County      South  -81.09983  32.08354   10946.058
# 1      Indiana   Johnson County    Midwest  -86.10665  39.61366   13969.098
# 2   California   Alameda County       West -121.87468  37.66243    4108.440
# 3      Indiana    Monroe County    Midwest  -86.52639  39.16533    7201.964
# 4  Connecticut  Hartford County  Northeast  -72.52443  41.77524   10082.160
#
#       profit
# 0   4048.542
# 1  11899.602
# 2   1760.760
# 3   9166.136
# 4   8249.040

# %%
rj['margin_pct'] = rj['profit']/rj['line_total'] * 100
rj.head()
# Out:
#      order_name order_date     customer_name channel_name  order_qty  \
# 0   SO - 000225 2023-01-01     Rhynoodle Ltd    Wholesale          6
# 1  SO - 0003378 2020-01-01    Thoughtmix Ltd  Distributor         11
# 2  SO - 0005126 2020-01-01   Amerisourc Corp    Wholesale          6
# 3  SO - 0005614 2022-01-01  Colgate-Pa Group       Export          7
# 4  SO - 0005781 2021-01-01     Deseret Group    Wholesale          8
#
#   product_name  unit_name  line_total  total_unit_cost state_code  \
# 0   Product 27     2499.1     14994.6         1824.343         GA
# 1   Product 20     2351.7     25868.7         1269.918         IN
# 2   Product 26      978.2      5869.2          684.740         CA
# 3    Product 7     2338.3     16368.1         1028.852         IN
# 4    Product 8     2291.4     18331.2         1260.270         CT
#
#          state           county     region  longitude  latitude  total_cost  \
# 0      Georgia   Chatham County      South  -81.09983  32.08354   10946.058
# 1      Indiana   Johnson County    Midwest  -86.10665  39.61366   13969.098
# 2   California   Alameda County       West -121.87468  37.66243    4108.440
# 3      Indiana    Monroe County    Midwest  -86.52639  39.16533    7201.964
# 4  Connecticut  Hartford County  Northeast  -72.52443  41.77524   10082.160
#
#       profit  margin_pct
# 0   4048.542        27.0
# 1  11899.602        46.0
# 2   1760.760        30.0
# 3   9166.136        56.0
# 4   8249.040        45.0

# %%
#  EDA

# %%
rj['order_month'] = rj['order_date'].dt.to_period('M')
rs= rj.groupby('order_month')['line_total'].sum()
rs.plot(marker='o', color='b')  

plt.xlabel('Order Month')
plt.ylabel('Total Sales (line_total)')
plt.title('Monthly Sales Trend')
plt.grid(True,linestyle='--')
plt.show()

# %%
# rj['order_month_name'] = rj['order_date'].dt.month_name()
# rj['order_month_num'] = rj['order_date'].dt.month
# monthly_sales = rj.groupby(['order_month_num','order_month_name'])['line_total'].sum().sort_index()
# plt.figure(figsize=(15, 4))
# monthly_sales.plot(marker = 'o',color = 'r')
# plt.title('Mounth wise sales')
# plt.xlabel('order_month_name')
# plt.ylabel('line_total')
# plt.grid(True, linestyle='--', alpha=0.5)
# plt.xticks(rotation=45)

# plt.show()

from matplotlib.ticker import EngFormatter


rj['order_date'] = pd.to_datetime(rj['order_date'])

rj['month_num'] = rj['order_date'].dt.month
rj['month_name'] = rj['order_date'].dt.month_name()

monthly = rj.groupby(['month_num', 'month_name'])['line_total'].sum()

month_order = [(i, pd.to_datetime(str(i), format='%m').strftime('%B')) for i in range(1, 13)]
index = pd.MultiIndex.from_tuples(month_order, names=['month_num', 'month_name'])
monthly = monthly.reindex(index, fill_value=0)

monthly.index = monthly.index.droplevel(0)

plt.figure(figsize=(15, 4))
plt.plot(monthly.index, monthly.values, marker='o', color='b', linewidth=2)

formatter = EngFormatter(unit='', places=1)
plt.gca().yaxis.set_major_formatter(formatter)

plt.title('Sales Aggregated by Calendar Month (All 12 Months)')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
rj['order_month_name'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
# top_ten = rj.groupby("product_name")['line_total'].sum().sort_values(ascending=False).head(10)

# plt.figure(figsize=(12, 6))
# top_ten.plot(kind='bar', color='skyblue')


# plt.title('Top 10 Products by Total Sales')
# plt.xlabel('Product Name')
# plt.ylabel('Total Sales (line_total)')
# plt.xticks(rotation=45, ha='right')  
# plt.grid(axis='y', linestyle='--', alpha=0.5)
# plt.tight_layout()


# plt.show()

import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Prepare data
top_ten = rj.groupby("product_name")['line_total'].sum().sort_values(ascending=False).head(10)
top_ten_df = top_ten.reset_index()

# Step 2: Plot using hue as product_name to get different colors
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

barplot = sns.barplot(
    data=top_ten_df,
    x='product_name',
    y='line_total',
    hue='product_name',         # Different color per product
    dodge=False,
    legend = True,
    palette='tab10'             # Try 'tab10', 'Set2', 'Dark2', etc.
)

# Step 3: Remove duplicate legend labels (optional)
handles, labels = barplot.get_legend_handles_labels()
barplot.legend(handles=handles[:1], labels=["Products"], title="Legend")

# Step 4: Add value labels
for index, row in top_ten_df.iterrows():
    plt.text(index, row['line_total'], f"{row['line_total']:.0f}",
             ha='center', va='bottom', fontsize=9, fontweight='bold')

# Step 5: Final styling
plt.title('Top 10 Products by Total Sales')
plt.xlabel('Product Name')
plt.ylabel('Total Sales (line_total)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
